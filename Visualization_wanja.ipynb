# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
sns.set(style="darkgrid")

# %%
#Define df as our Dataset and set date as our index for the Dataset
df_v = pd.read_csv("data_clean_WITHOUT_dummies.csv")
df_v = df_v.drop(labels=range(0,144), axis=0) #Drop the first 144 rows to start with a monday and have better Visualization. The 144 Rows dont matter since we have over 15000
df_v = df_v.set_index('date')

# %%
df_v
# Out:
#             Unnamed: 0      time weekday  pedestrians count  \
# date
# 2018-05-07         144  00:00:00  Monday                 84
# 2018-05-07         145  01:00:00  Monday                 40
# 2018-05-07         146  02:00:00  Monday                 26
# 2018-05-07         147  03:00:00  Monday                  7
# 2018-05-07         148  04:00:00  Monday                 22
# ...                ...       ...     ...                ...
# 2020-01-31       15353  19:00:00  Friday               5422
# 2020-01-31       15354  20:00:00  Friday               2691
# 2020-01-31       15355  21:00:00  Friday               1329
# 2020-01-31       15356  22:00:00  Friday                915
# 2020-01-31       15357  23:00:00  Friday                525
#
#             temperature in ºc    weather condition  holiday  school holiday  \
# date
# 2018-05-07               17.0          clear-night        0               0
# 2018-05-07               16.0          clear-night        0               0
# 2018-05-07               14.0          clear-night        0               0
# 2018-05-07               13.0          clear-night        0               0
# 2018-05-07               12.0          clear-night        0               0
# ...                       ...                  ...      ...             ...
# 2020-01-31               11.0  partly-cloudy-night        0               0
# 2020-01-31               11.0  partly-cloudy-night        0               0
# 2020-01-31               10.0  partly-cloudy-night        0               0
# 2020-01-31               11.0               cloudy        0               0
# 2020-01-31               11.0               cloudy        0               0
#
#             months  hour
# date
# 2018-05-07       5     0
# 2018-05-07       5     1
# 2018-05-07       5     2
# 2018-05-07       5     3
# 2018-05-07       5     4
# ...            ...   ...
# 2020-01-31       1    19
# 2020-01-31       1    20
# 2020-01-31       1    21
# 2020-01-31       1    22
# 2020-01-31       1    23
#
# [15214 rows x 10 columns]

# %%
fig, axs = plt.subplots(figsize=(12, 8))
sns.boxplot(data=df_v, y="pedestrians count", x="weekday", palette="muted", showmeans=True,
     meanprops={"marker":"o", "markerfacecolor":"white", "markeredgecolor":"black","markersize":"5"})

axs.legend(handles=[(plt.Line2D([], [], marker="o", color="white", markeredgecolor="black", linewidth=0, label="mean"))])

# %%
fig, axs = plt.subplots(figsize=(12, 8))
sns.boxplot(data=df_v, y="pedestrians count", x="months", palette="muted", showmeans=True,
     meanprops={"marker":"o", "markerfacecolor":"white", "markeredgecolor":"black","markersize":"5"})

axs.legend(handles=[(plt.Line2D([], [], marker="o", color="white", markeredgecolor="black", linewidth=0, label="mean"))])

# %%
fig, axs = plt.subplots(figsize=(12, 8))
sns.boxplot(data=df_v, x="pedestrians count", y="weather condition", palette="muted", showmeans=True,
     meanprops={"marker":"o", "markerfacecolor":"white", "markeredgecolor":"black","markersize":"5"}) 

axs.legend(handles=[(plt.Line2D([], [], marker="o", color="white", markeredgecolor="black", linewidth=0, label="mean"))])

# %%
import matplotlib.patches as mpatches
fig, axs = plt.subplots(figsize=(12, 8))
sns.boxplot(data=df_v, x="hour", y="pedestrians count", palette="muted", showmeans=True,
    meanprops={"marker":"o", "markerfacecolor":"white", "markeredgecolor":"black","markersize":"5"})

axs.legend(handles=[(plt.Line2D([], [], marker="o", color="white", markeredgecolor="black", linewidth=0, label="mean"))])

# %%
fig, axs = plt.subplots(figsize=(12, 8))
sns.boxplot(data=df_v, x="hour", y="pedestrians count", palette="muted", hue="holiday", showmeans=True,
    meanprops={"marker":"o", "markerfacecolor":"white", "markeredgecolor":"black","markersize":"5"})  

axs.legend(handles=[(plt.Line2D([], [], marker="o", color="white", markeredgecolor="black", linewidth=0, label="mean")), plt.bar([],[],label="test"), plt.bar([],[],label="jaa", color="red")])

fig.show()
# Out:
# /var/folders/lj/x77cgrfn0ml3pv3407q8vw0c0000gn/T/ipykernel_11869/3162961674.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, axs = plt.subplots(figsize=(12,8))
sns.boxplot(data=df_v, x="hour", y="pedestrians count", palette="muted", hue="school holiday", showmeans=True,
     meanprops={"marker":"o", "markerfacecolor":"white", "markeredgecolor":"black","markersize":"5"})

fig.show()
# Out:
# /var/folders/lj/x77cgrfn0ml3pv3407q8vw0c0000gn/T/ipykernel_11869/548014976.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
